# %% [markdown]
# Voltmeter test

# %%
def volts(val):
    return (5*val)/1024

# %%
print(volts(1000))
# Out:
# 4.8828125

# %%
val = 1000
x = ((int)(5*val/4))/256
print(x)
# Out:
# 4.8828125

# %%
int_volts = 0
dec_volts = 95
if int_volts < 2 and dec_volts < 20:
    print("Low voltage")
elif int_volts < 1:
    print("Low voltage")
else:
    print("Ok")
# Out:
# Low voltage
